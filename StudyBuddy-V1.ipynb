# %% [markdown]
# <a href="https://colab.research.google.com/github/ppradyoth/ML-101-Workshop/blob/main/StudyBuddy-V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📘 StudyBuddy: Ask Your PDF Anything — Gemini API Project

# ✅ STEP 1: Install Required Libraries
# !pip install -q google-generativeai PyMuPDF

# ✅ STEP 2: Import Libraries
import google.generativeai as genai
import fitz  # PyMuPDF
import os
import textwrap
from google.colab import files
from google.colab import userdata

# ✅ STEP 3: Configure Gemini API
userdata.get('GEMINI_API_KEY')
# ✅ STEP 3: Configure Gemini API
genai.configure(api_key=GEMINI_API_KEY)

# ✅ STEP 4: Upload a PDF
print("📂 Upload your PDF file (e.g., study notes):")
uploaded = files.upload()
pdf_path = list(uploaded.keys())[0]

# ✅ STEP 5: Extract text from PDF using PyMuPDF
def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

document_text = extract_text_from_pdf(pdf_path)

#for m in genai.list_models():
#   print(m.name, m.supported_generation_methods)


# ✅ STEP 6: Load Gemini Model
model = genai.GenerativeModel("gemini-2.5-pro")

# ✅ STEP 7: Ask Questions Based on PDF
def ask_gemini_about_pdf(question, context):
    prompt = f"""You are StudyBuddy, an academic assistant.
Use the context below to answer the question as accurately as possible.

Context:
\"\"\"
{context}
\"\"\"

Question: {question}
Answer:"""
    response = model.generate_content(prompt)
    return response.text.strip()

# ✅ STEP 8: Loop for Interaction
while True:
    question = input("💬 Ask a question about the PDF (or type 'exit'): ")
    if question.lower() == 'exit':
        break
    answer = ask_gemini_about_pdf(question, document_text)
    print("\n🤖 Gemini Answer:\n")
    print(textwrap.fill(answer, width=100))
    print("-" * 80)
# Out:
# 📂 Upload your PDF file (e.g., study notes):
#      <input type="file" id="files-9b148215-386a-4985-bc23-e800041b486a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b148215-386a-4985-bc23-e800041b486a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
